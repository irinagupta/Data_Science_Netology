# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм со столбцами: <дата> - <заголовок> - <ссылка>.

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст статьи>

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_all_links(url, query):
    """Собирает ссылки на статьи в результатах поиска"""
    links_list = []
    params = {
        'q': query,
        'order_by': 'relevance'
    }
    res = requests.get(URL, params)
    time.sleep(0.3)
    soup = BeautifulSoup(res.text, 'html.parser')
    search_blocks = soup.find_all('h2', class_='post__title')
    links_list = list(map(lambda x: x.find('a').get('href'), search_blocks))
    return links_list

KEYWORDS = ['python', 'парсинг']
URL = 'https://habr.com/ru/search/'
all_links = []
for word in KEYWORDS:
    links = get_all_links(URL, word)
    all_links = all_links + links

# %%
habr_search = pd.DataFrame()
for links in all_links:
    soup = BeautifulSoup(requests.get(links).text, 'html.parser')
    time.sleep(0.3)
    date = soup.find('span', class_='post__time').text
    title = soup.find('span', class_='post__title-text').text
    article_text = soup.find('div', class_='post__text post__text-html post__text_v1').text
    row = {'date': date, 'title': title, 'link': links, 'article_text': article_text}
    habr_search = pd.concat([habr_search, pd.DataFrame([row])])  
habr_search
# Out:
#                        date  \
# 0    21 апреля 2020 в 18:35
# 0      3 марта 2020 в 13:22
# 0       3 июня 2020 в 09:00
# 0   31 октября 2019 в 10:02
# 0  16 сентября 2020 в 16:48
# 0       9 июля 2012 в 10:21
# 0    9 декабря 2012 в 07:16
# 0    3 февраля 2013 в 17:26
# 0   10 февраля 2013 в 12:24
# 0   17 февраля 2013 в 17:37
# 0    25 ноября 2013 в 12:41
# 0   18 декабря 2013 в 10:12
# 0   23 октября 2015 в 15:45
# 0   7 сентября 2017 в 18:28
# 0     8 ноября 2018 в 14:00
# 0   29 августа 2018 в 12:52
# 0    3 октября 2018 в 16:31
# 0       3 июня 2019 в 12:18
# 0      12 июня 2019 в 09:53
# 0       26 мая 2020 в 11:52
# 0     3 апреля 2019 в 15:21
# 0        7 мая 2019 в 14:51
# 0   17 октября 2017 в 14:04
# 0    1 декабря 2016 в 12:46
# 0      3 марта 2016 в 16:39
# 0      18 июня 2018 в 23:42
# 0   28 августа 2019 в 14:12
# 0      14 июня 2011 в 19:24
# 0     18 марта 2015 в 17:52
# 0      6 марта 2015 в 17:40
# 0     23 марта 2019 в 20:36
# 0   26 февраля 2018 в 10:28
# 0      23 июля 2020 в 15:17
# 0       8 июня 2020 в 17:46
# 0      19 июля 2015 в 15:27
# 0   14 февраля 2013 в 14:46
# 0       25 мая 2009 в 21:15
# 0   2 сентября 2011 в 14:37
# 0   16 декабря 2015 в 11:45
# 0    11 ноября 2016 в 10:56
#
#                                                title  \
# 0  Вышел Python 2.7.18, последний релиз ветки Pyt...
# 0  В начале этого года Python сместил Java и стал...
# 0  Вышла версия 0.0.2 snakeware — дистрибутива Li...
# 0  Создатель Python Гвидо ван Россум ушел из Drop...
# 0  Астрономам порекомендовали меньше использовать...
# 0                                   Мысли о Python 3
# 0  Дружим Python 3 с MS Visual C++. Строим мост в...
# 0  Объединяя C++ и Python. Тонкости Boost.Python....
# 0  Конвертация типов в Boost.Python. Делаем преоб...
# 0  Путешествие исключений между C++ и Python или ...
# 0                             Менеджер версий python
# 0                                    Python на Хабре
# 0  10 приложений для изучения Python на Android-у...
# 0                                Что за чёрт, Python
# 0         Совмещение R и Python: зачем, когда и как?
# 0                         Бинарные модули для Python
# 0                                Python 3 в Facebook
# 0                    Указатели в Python: в чём суть?
# 0  Объектно-ориентированное программирование в Ja...
# 0  Python.org рекомендует: Программирование для Н...
# 0  Правда про парсинг сайтов, или «все интернет-м...
# 0   Парсинг сайтов — а это вообще легально в России?
# 0  Парсинг сайтов: как с точки зрения закона выгл...
# 0  Пример использования Product API от Fetchee дл...
# 0  Теория и практика парсинга исходников с помощь...
# 0               Парсинг и работа с Codable в Swift 4
# 0  Парсинг и анализ семантики для SEO: 5 бесплатн...
# 0     Парсинг на Pуthon. Как собрать архив Голубятен
# 0         Продвинутый парсинг веб-сайтов с Mechanize
# 0                                Веб-парсинг на Ruby
# 0  Искусство парсинга 2 или транслитерация собств...
# 0  Парсинг telegram каналов для агрегатора контен...
# 0  Как проанализировать рынок фотостудий с помощь...
# 0  Парсинг YouTube, включая подгружаемые данные, ...
# 0            Использование morph.io для веб-парсинга
# 0  Парсинг сайтов-магазинов. Личный опыт и немног...
# 0                         Еще о парсинге на Prolog'е
# 0       Grab — python библиотека для парсинга сайтов
# 0                Парсинг формул в 50 строк на Python
# 0  Product API от Fetchee: автоматический парсинг...
#
#                                                 link  \
# 0                 https://habr.com/ru/news/t/498364/
# 0  https://habr.com/ru/company/itsumma/news/t/490...
# 0                 https://habr.com/ru/news/t/505096/
# 0                 https://habr.com/ru/news/t/473926/
# 0                 https://habr.com/ru/news/t/519414/
# 0                   https://habr.com/ru/post/147281/
# 0                   https://habr.com/ru/post/161931/
# 0                   https://habr.com/ru/post/168083/
# 0                   https://habr.com/ru/post/168827/
# 0                   https://habr.com/ru/post/169639/
# 0                   https://habr.com/ru/post/203516/
# 0                   https://habr.com/ru/post/205944/
# 0                   https://habr.com/ru/post/269411/
# 0    https://habr.com/ru/company/mailru/blog/337364/
# 0       https://habr.com/ru/company/ods/blog/348260/
# 0  https://habr.com/ru/company/oleg-bunin/blog/41...
# 0      https://habr.com/ru/company/otus/blog/425233/
# 0    https://habr.com/ru/company/mailru/blog/454324/
# 0                   https://habr.com/ru/post/455796/
# 0  https://habr.com/ru/company/skillfactory/blog/...
# 0                   https://habr.com/ru/post/446488/
# 0                   https://habr.com/ru/post/450834/
# 0                   https://habr.com/ru/post/340302/
# 0   https://habr.com/ru/company/fetchee/blog/316558/
# 0        https://habr.com/ru/company/pt/blog/210772/
# 0                   https://habr.com/ru/post/414221/
# 0     https://habr.com/ru/company/click/blog/465277/
# 0                   https://habr.com/ru/post/121815/
# 0                   https://habr.com/ru/post/253439/
# 0                   https://habr.com/ru/post/252379/
# 0                   https://habr.com/ru/post/444876/
# 0                   https://habr.com/ru/post/349942/
# 0                   https://habr.com/ru/post/504900/
# 0                   https://habr.com/ru/post/505888/
# 0                   https://habr.com/ru/post/262991/
# 0                   https://habr.com/ru/post/169409/
# 0                    https://habr.com/ru/post/60430/
# 0                   https://habr.com/ru/post/127584/
# 0                   https://habr.com/ru/post/273253/
# 0   https://habr.com/ru/company/fetchee/blog/314960/
#
#                                         article_text
# 0  \r\n20 апреля 2020 года, спустя почти десять л...
# 0  Согласно отчету RedMonk за январь 2020 года, P...
# 0  \n\r\n31 мая 2020 года разработчик Джош Мур (J...
# 0  \n\r\nСоздатель языка программирования Python ...
# 0  \n\r\nАстрономы из Лейденской обсерватории опу...
# 0  Предлагаю вашему вниманю пересказ замечательно...
# 0  Всем доброго {daytime}!\n\r\nСегодня пришла по...
# 0  Boost.Python во всех отношениях замечательная ...
# 0  Данная статья не является продолжением повеств...
# 0  В этой главе сказа про дружбу C++ и Python буд...
# 0  Иногда полезно держать несколько версий python...
# 0  Некоторое время назад, в силу определенных при...
# 0  В процессе изучения языка мы обычно пользуемся...
# 0  \nНедавно мы писали о забавных, хитрых и стран...
# 0  \n\r\nНаверное, многие из тех, кто занимается ...
# 0  Python — классный. Мы говорим «pip install» и ...
# 0  Всем привет!\n\r\nЗапустили юбилейный пятый по...
# 0  \r\nЕсли вы когда-нибудь работали с такими низ...
# 0  Привет, Хабр! Представляю вашему вниманию пере...
# 0  Предлагаем вашему вниманию подборку материалов...
# 0  В этой статье я постараюсь наиболее просто рас...
# 0  По одному из определений парсинг есть синтакси...
# 0  \r\nПопробуем рассмотреть один из лучших спосо...
# 0  \n\r\nВ этой инструкции мы расскажем о том, ка...
# 0  В нашем проекте PT Application Inspector реали...
# 0  \n\r\nФормат JSON приобрел большую популярност...
# 0  \nКогда работаешь с семантикой, постепенно «об...
# 0  Статья описывает разработку скрипта на языке P...
# 0  В продолжение темы парсинга сайтов на Ruby, я ...
# 0  \nЭто перевод статьи «Web Scraping with Ruby»,...
# 0  +БОНУС: взаимное включение классов друг в друг...
# 0  Привет, Хабр!\n\r\nНесколько лет назад я начал...
# 0  В интернете огромное количество открытых данны...
# 0  Вступление\r\nЧтобы подгрузить данные контента...
# 0  Если вы читали предыдущие две статьи, Веб-парс...
# 0  Разделим парсинг (скраппинг) сайтов на две под...
# 0  Вот тут наткнулся на, в общем-то, простую зада...
# 0  Лет пять-шесть назад, когда я ещё программиров...
# 0  Вдохновение — задача с собеседования Яндекса и...
# 0  UPD: Сегодня отправили ключи доступа к API все...

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>.

# %%
def check_avast(url,emails):
    """Проверяет список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck"""
    avast_leaks = pd.DataFrame()
    for email in emails:
        post_result = requests.post(url, json={"email" : email})
        for leak in post_result.json()['value']:
            row = {'email': email,
                   'date': leak['leak_info']['date'],
                   'source of leak': leak['leak_info']['title'], 
                   'description': leak['leak_info']['description']}
            avast_leaks = pd.concat([avast_leaks, pd.DataFrame([row])])
    return avast_leaks

URL = "https://digibody.avast.com/v1/web/leaks"
emails = ['xxx@x.ru', 'yyy@y.com', 'zzz@z.com', 'example@example.com']
df = check_avast(URL,emails)
df
# Out:
#                   email           date                        source of leak  \
# 0              xxx@x.ru  1513900800000  Combolist of 1.4 Billion Credentials
# 0              xxx@x.ru  1549411200000              Collection #4 Combo List
# 0              xxx@x.ru  1485820800000                        CD Projekt Red
# 0              xxx@x.ru  1487030400000                                Parapa
# 0              xxx@x.ru  1488931200000                      Sensitive Source
# ..                  ...            ...                                   ...
# 0   example@example.com  1595462400000                               Wattpad
# 0   example@example.com  1600905600000                 Terabase64 Combo List
# 0   example@example.com  1597881600000                     Gaming Combo List
# 0   example@example.com  1596672000000                      Sensitive Source
# 0   example@example.com  1597276800000       "AntiPub Drugs Squad" Combolist
#
#                                           description
# 0   The proliferation of stolen or leaked database...
# 0   On January 7, 2019, an online user named Sanix...
# 0   In March 2016, CDProjektRed.com.com's forum da...
# 0   In July and August 2016, two criminals execute...
# 0   This source has been marked as sensitive due t...
# ..                                                ...
# 0   In June 2020, the online writing community Wat...
# 0   The Terabase64 Combo List is a combolist origi...
# 0   At an unconfirmed date, an unidentified gaming...
# 0   This source has been marked as sensitive due t...
# 0   In August 2020, this combolist was shared on a...
#
# [148 rows x 4 columns]

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>.
