# %%
import pandas as pd

from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, silhouette_score

from sklearn.preprocessing import StandardScaler

from matplotlib import pyplot as plt

# %%
data = pd.read_excel('geo.xlsx')

# %%
data.head()

# %% [markdown]
# Кластеризуем данные без расчета оптимального количетсва кластеров

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(data.loc[:,['x', 'y']])
#X_comm = scaler.fit_transform(data.loc[:,['x', 'y', 'comment_class']])

# %%
model = KMeans()

# %%
clusters = model.fit_predict(X_scaled)
centers = model.cluster_centers_
plt.scatter(X_scaleddata_scaled, X_scaled[:, 1], c=clusters, cmap='autumn', s=60)
plt.scatter(centers[:, 0], centers[:, 1], s=50)

# %% [markdown]
# Определим оптимальное количество кластеров

# %%
k_inertia = []
ks = range(1,11)

for k in ks:
    clf_kmeans = KMeans(n_clusters=k)
    clusters_kmeans = clf_kmeans.fit_predict(X_scaled)
    k_inertia.append(clf_kmeans.inertia_)

# %%
plt.plot(ks, k_inertia)

# %% [markdown]
# Оптимальное количество кластеров примем равное 4 и снова проведем кластеризацию

# %%
new_model = KMeans(n_clusters=4)
new_clusters = new_model.fit_predict(X_scaled)
new_centers = new_model.cluster_centers_
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=new_clusters, cmap='autumn', s=60)
plt.scatter(new_centers[:, 0], new_centers[:, 1], s=50)

# %% [markdown]
# Посмотрим кластеризацию для голосов за и против отдельно
# Для этого разобъем данные на два датасета

# %%
X_positive = data[data.comment_class == 1]
del X_positive['Unnamed: 0']
X_negative = data[data.comment_class == -1]
del X_negative['Unnamed: 0']
X_positive = scaler.fit_transform(X_positive)
X_negative = scaler.fit_transform(X_negative)

# %%
k_inertia_pos = []
k_inertia_neg = []
ks = range(1,11)

for k in ks:
    model = KMeans(n_clusters=k)
    clusters_kmeans = model.fit_predict(X_positive)
    k_inertia_pos.append(model.inertia_)
    clusters_kmeans = model.fit_predict(X_negative)
    k_inertia_neg.append(model.inertia_)

# %%
plt.plot(ks, k_inertia_pos, color = 'blue')
plt.plot(ks, k_inertia_pos ,'ro')
plt.plot(ks, k_inertia_neg, color = 'green')
plt.plot(ks, k_inertia_neg,'ro')
plt.grid()
plt.show()

# %% [markdown]
# для позитивных данных количество кластеров возьмем = 3, а для негативных = 5

# %%
model_pos = KMeans(n_clusters=3)
clusters_pos = model_pos.fit_predict(X_positive)
centers_pos = model_pos.cluster_centers_
plt.scatter(X_positive[:, 0], X_positive[:, 1], c=clusters_pos, cmap='autumn', s=60)
plt.scatter(centers_pos[:, 0], centers_pos[:, 1], s=50)

# %%
model_neg = KMeans(n_clusters=5)
clusters_neg = model_neg.fit_predict(X_negative)
centers_neg = model_neg.cluster_centers_
plt.scatter(X_negative[:, 0], X_negative[:, 1], c=clusters_neg, cmap='autumn', s=60)
plt.scatter(centers_neg[:, 0], centers_neg[:, 1], s=50)
